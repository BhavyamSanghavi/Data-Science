# %%
import pandas as pd
import seaborn as sb

# %%
df=pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Features and their types

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# ## Histograms of All Features

# %%
sb.histplot(df['SepalLengthCm'])
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sb.histplot(df['SepalWidthCm'])
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sb.histplot(df['PetalLengthCm'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
sb.histplot(df['PetalWidthCm'], kde=True)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
sb.histplot(df['Species'])
# Out:
# <Axes: xlabel='Species', ylabel='Count'>

# %% [markdown]
# ## Box Plot for All Features

# %%
sb.boxplot(data=df, x='Species', y='SepalLengthCm')
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sb.boxplot(data=df, x='Species', y='SepalWidthCm')
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sb.boxplot(data=df, x='Species', y='PetalLengthCm')
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sb.boxplot(data=df, x='Species', y='PetalWidthCm')
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
sb.boxplot( y='SepalLengthCm', x='SepalWidthCm',data=df)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='SepalLengthCm'>
