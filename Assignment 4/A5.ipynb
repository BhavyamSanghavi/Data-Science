# %%
import pandas as pd
import seaborn as sb

# %%
df=pd.read_csv('Titanic.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Cabin'].fillna('Unknown',inplace=True) 
df['Embarked'].fillna('Unknown',inplace=True)
# fill the values of fare where fare is zero with the mean of the fare
mean=df['Fare'].mean()  
row=df['Fare']
for i in range(len(df['Fare'])):
    if row[i]<30:
        row[i]=mean
# df.isnull().sum()
# Out:
# /tmp/ipykernel_9073/3332342936.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)
# /tmp/ipykernel_9073/3332342936.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
sb.boxplot(x=df['Sex'],y=df['Age'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sb.boxplot(x=df['Survived'],y=df['Age'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sb.boxplot(x=df['Survived'],y=df['Fare'])
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
sb.boxplot(y=df['Fare'],x=df['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %%
sb.boxplot(y=df['Age'],x=df['SibSp'])
# Out:
# <Axes: xlabel='SibSp', ylabel='Age'>

# %%
sb.boxplot(y=df['Fare'],x=df['Parch'])
# Out:
# <Axes: xlabel='Parch', ylabel='Fare'>

# %%
sb.boxplot(y=df['Fare'],x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sb.boxplot(y=df['Age'],x=df['SibSp'])
# Out:
# <Axes: xlabel='SibSp', ylabel='Age'>

# %%
sb.boxplot(y=df['Age'],x=df['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>
